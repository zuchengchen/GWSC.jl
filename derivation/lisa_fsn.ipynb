# %%
include("main.jl");
# lisa = LISA();

# %%
fs = 10 .^ range(-5, 0, length=10^4);
fsn = sqrt.(fs .* getSn.(fs));

# %%
using DelimitedFiles

open("lisa_fsn.txt", "w") do io
    writedlm(io, [fs fsn], " ")
end;
