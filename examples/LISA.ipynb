# %% [markdown]
# ### File path of transer function for LISA should be fixed in the future version!

# %%
using GWSC, PyPlot
lisa = LISA();

lisa1 = LISA(approRQ=true);
# Out:
# ArgumentError: Cannot open 'RLISA.txt': not a file
#
# Stacktrace:
#  [1] #readdlm_auto#9(::Base.Iterators.Pairs{Union{},Union{},Tuple{},NamedTuple{(),Tuple{}}}, ::Function, ::String, ::Char, ::Type, ::Char, ::Bool) at /build/julia/src/julia-1.1.1/usr/share/julia/stdlib/v1.1/DelimitedFiles/src/DelimitedFiles.jl:233
#  [2] readdlm_auto at /build/julia/src/julia-1.1.1/usr/share/julia/stdlib/v1.1/DelimitedFiles/src/DelimitedFiles.jl:233 [inlined]
#  [3] #readdlm#5 at /build/julia/src/julia-1.1.1/usr/share/julia/stdlib/v1.1/DelimitedFiles/src/DelimitedFiles.jl:172 [inlined]
#  [4] readdlm at /build/julia/src/julia-1.1.1/usr/share/julia/stdlib/v1.1/DelimitedFiles/src/DelimitedFiles.jl:172 [inlined]
#  [5] #readdlm#3 at /build/julia/src/julia-1.1.1/usr/share/julia/stdlib/v1.1/DelimitedFiles/src/DelimitedFiles.jl:118 [inlined]
#  [6] readdlm at /build/julia/src/julia-1.1.1/usr/share/julia/stdlib/v1.1/DelimitedFiles/src/DelimitedFiles.jl:118 [inlined]
#  [7] #RLISA#18(::Bool, ::Function, ::Float64, ::Int64) at /home/bear/projects/working/GWSC.jl/src/LISA/LISA.jl:26
#  [8] #RLISA at ./none:0 [inlined]
#  [9] #LISA#23 at /home/bear/projects/working/GWSC.jl/src/LISA/LISA.jl:170 [inlined]
#  [10] LISA() at /home/bear/projects/working/GWSC.jl/src/LISA/LISA.jl:169
#  [11] top-level scope at In[1]:2

# %% [markdown]
# ## Figure 2

# %%
f = 10 .^ (-5:0.001:0)
R = lisa.R.(f)
R1 = lisa1.R.(f)

loglog(f, R)
loglog(f, R1)

legend(["numerical", "fit"])
xlabel("Frequency (Hz)")
ylabel("R ")
show()
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)

# %% [markdown]
# ## Figure 3

# %%
plotSpectralDensity(lisa, plotPnQ=true)
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)

# %% [markdown]
# ## Figure 4

# %%
plotSpectralDensity(lisa, plotSnCQ=true)
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)

# %% [markdown]
# ## Figure 8

# %%
plotCharacteristicStrain(lisa, plotSnQ=true)
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)

# %% [markdown]
# ## Power-law integrated curve

# %%
@time plotΩPI(lisa, plotΩeffQ=true, plotΩPILinesQ=true)
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
#   5.843213 seconds (12.14 M allocations: 1.072 GiB, 4.93% gc time)
