# %% [markdown]
# ### File path of transer function for LISA should be fixed in the future version!

# %%
using GWSC, PyPlot
lisa = LISA();

lisa1 = LISA(transfer_file="RLISA1");
# Out:
# Warning: Could not find transfer function file RLISA1!
# 	 Approximation will be used...

# %% [markdown]
# ## Figure 2

# %%
f = 10 .^ (-5:0.001:0)
R = lisa.R.(f)
R1 = lisa1.R.(f)

loglog(f, R)
loglog(f, R1)

legend(["numerical", "fit"])
xlabel("Frequency (Hz)")
ylabel("R ")
show()
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)

# %% [markdown]
# ## Figure 3

# %%
plotSpectralDensity(lisa, plotPn=true)
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)

# %% [markdown]
# ## Figure 4

# %%
plotSpectralDensity(lisa, plotSnC=true)
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)

# %% [markdown]
# ## Figure 8

# %%
plotCharacteristicStrain(lisa, plotSn=true)
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)

# %% [markdown]
# ## Power-law integrated curve

# %%
@time plotΩPI(lisa, plotΩeff=true, plotΩPILines=true)
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
#  17.762993 seconds (84.60 M allocations: 4.699 GiB, 3.76% gc time)
