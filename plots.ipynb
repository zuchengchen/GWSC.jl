# %%
include("main.jl");
lisa = LISA();
lisa1 = LISA(transfer_file="RLISA1.txt");
# Out:
# Warning: Could not find transfer function file RLISA1.txt!
# 	 Approximation will be used...

# %% [markdown]
# ## Figure 2

# %%
f = 10 .^ (-5:0.001:0)
R = lisa.R.(f)
R1 = lisa1.R.(f)

loglog(f, R)
loglog(f, R1)

legend(["numerical", "fit"])
xlabel("Frequency (Hz)")
ylabel("R ")
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# PyObject Text(24.000000000000007, 0.5, 'R ')

# %% [markdown]
# ## Figure 3

# %%
plotSpectralDensity(lisa, plotPn=true)
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)

# %% [markdown]
# ## Figure 4

# %%
plotSpectralDensity(lisa, plotSnC=true)
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)

# %% [markdown]
# ## Figure 8

# %%
plotCharacteristicStrain(lisa, plotSn=true)
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
